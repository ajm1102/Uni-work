# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 

x_train = pd.read_csv('./bbdc_2018/train-en.csv', usecols=['wind_speed48M'])
y_train = pd.read_csv('./bbdc_2018/train-en.csv', usecols=['Output'])

# %%
# Exercise 2 

x_train.describe()
# Out:
#        wind_speed48M
# count   52508.000000
# mean        5.626846
# std         2.466787
# min         0.550000
# 25%         3.925000
# 50%         5.330000
# 75%         6.965000
# max        18.870000

# %%
y_train.describe()
# Out:
#               Output
# count   52508.000000
# mean    27293.661461
# std     29313.824237
# min     -1628.000000
# 25%      4928.000000
# 50%     17300.000000
# 75%     40415.000000
# max    120520.000000

# %%
# Exercise 2 


plt.scatter(x_train["wind_speed48M"], y_train["Output"], color="cyan", s=0.2) 
plt.show()

# %%
y_train["Output"].value_counts(bins=20)
# Out:
# (-1750.149, 4479.4]     12591
# (4479.4, 10586.8]        7361
# (10586.8, 16694.2]       5842
# (16694.2, 22801.6]       4343
# (22801.6, 28909.0]       3703
# (28909.0, 35016.4]       3134
# (35016.4, 41123.8]       2690
# (41123.8, 47231.2]       2236
# (47231.2, 53338.6]       1866
# (53338.6, 59446.0]       1432
# (59446.0, 65553.4]       1157
# (65553.4, 71660.8]        992
# (114412.6, 120520.0]      834
# (71660.8, 77768.2]        814
# (77768.2, 83875.6]        727
# (108305.2, 114412.6]      703
# (83875.6, 89983.0]        622
# (89983.0, 96090.4]        510
# (102197.8, 108305.2]      493
# (96090.4, 102197.8]       458
# Name: Output, dtype: int64

# %%
y_train["Output"]
# Out:
# 0        79168
# 1        75124
# 2        76072
# 3        67964
# 4        69988
#          ...
# 52503    13688
# 52504    17624
# 52505    18528
# 52506    15836
# 52507    15712
# Name: Output, Length: 52508, dtype: int64

# %%
y_train
# Out:
#        Output
# 0       79168
# 1       75124
# 2       76072
# 3       67964
# 4       69988
# ...       ...
# 52503   13688
# 52504   17624
# 52505   18528
# 52506   15836
# 52507   15712
#
# [52508 rows x 1 columns]
